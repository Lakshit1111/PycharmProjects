# %%
pip install ultralytics
# Out:
# ...
#   WARNING: Failed to remove contents in a temporary directory 'D:\PycharmProjects\.venv\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\PycharmProjects\.venv\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# ...
#   Using cached pillow-10.4.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# ...
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# ...
#    ---------------------------------------- 0.0/873.6 kB ? eta -:--:--
#    --------------------------------------- 873.6/873.6 kB 19.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
# ...

# %%
import cv2
import os

# %%
cap = cv2.VideoCapture("D:/PycharmProjects/object_detection/5052676-hd_1920_1080_30fps.mp4")
if not os.path.exists("D:/PycharmProjects/object_detection/5052676-hd_1920_1080_30fps.mp4"):
    print("Error: The video file does not exist at the provided path.")
print("aief")
# Out:
# aief

# %%
import cv2

cap = cv2.VideoCapture(0)
print(cap.isOpened())
while True:  # Loop while the camera is open
    ret, frame = cap.read()  # Capture a frame

    if not ret:  # If the frame is not captured successfully
        break  # Break out of the loop
    cv2.imshow("Video", frame)

    if cv2.waitKey(1) & 0xFF == 27:  # Break the loop when the Esc key is pressed
        break
    
cap.release()  # Release the camera
cv2.destroyAllWindows()  # Close all OpenCV windows
# Out:
# True

# %%
import ultralytics
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import ultralytics
#
# File d:\PycharmProjects\.venv\Lib\site-packages\ultralytics\__init__.py:11
#       8 # Set ENV Variables (place before imports)
#       9 os.environ["OMP_NUM_THREADS"] = "1"  # reduce CPU utilization during training
# ---> 11 from ultralytics.data.explorer.explorer import Explorer
#      12 from ultralytics.models import NAS, RTDETR, SAM, YOLO, FastSAM, YOLOWorld
#      13 from ultralytics.utils import ASSETS, SETTINGS
#
# File d:\PycharmProjects\.venv\Lib\site-packages\ultralytics\data\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .base import BaseDataset
#       4 from .build import build_dataloader, build_grounding, build_yolo_dataset, load_inference_source
#       5 from .dataset import (
#       6     ClassificationDataset,
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import ultralytics
#       2 ultralytics.checks()
#
# File d:\PycharmProjects\.venv\Lib\site-packages\ultralytics\__init__.py:11
#       8 # Set ENV Variables (place before imports)
#       9 os.environ["OMP_NUM_THREADS"] = "1"  # reduce CPU utilization during training
# ---> 11 from ultralytics.data.explorer.explorer import Explorer
#      12 from ultralytics.models import NAS, RTDETR, SAM, YOLO, FastSAM, YOLOWorld
#      13 from ultralytics.utils import ASSETS, SETTINGS
#
# File d:\PycharmProjects\.venv\Lib\site-packages\ultralytics\data\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .base import BaseDataset
#       4 from .build import build_dataloader, build_grounding, build_yolo_dataset, load_inference_source
#       5 from .dataset import (
# ...
